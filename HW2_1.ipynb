# %% [markdown]
# <a href="https://colab.research.google.com/github/sitthatkaja/DWDM21/blob/main/HW2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **สรุปเนื้อหา Chapter 2 : Intro. to data mining**
#
# ***
#
# Data คือข้อมูลชุดๆหนึ่งที่เราจะนำมาใช้งาน โดยวิชานี้จะใช้งาน Data ด้วยรูปแบบของ Matrix โดยมีเงื่อนไขว่า หาก Data มี Attibute ที่ลักษณะเหมือนกันคือข้อมูลที่ซ้ำกัน
#
# หมายเหตุ : แนวตั้ง (column) เราเรียกว่า Attribute คือคุณสมบัติที่ใช้อธิบายข้อมูล แนวนอน (row) เรียก Record เป็นข้อมูลแบบจุด

# %% [markdown]
# ![126058855-9267c9ba-8fb7-4cd8-ae96-f7d00834764f.png](data:image/png;base64,...)

# %% [markdown]
# *ตัวอย่างข้อมูลแบบ 2 มิติ ( 2 Dimension )*

# %% [markdown]
# ![126058866-94857e6e-cff5-4851-b686-5a0a57884356.png](data:image/png;base64,...)

# %% [markdown]
# *ตัวอย่างข้อมูลแบบ 3 มิติ ( 3 Dimension )*

# %% [markdown]
# ![126058877-b82fff87-e449-4d83-b097-e8ee69840b50.png](data:image/png;base64,...)

# %% [markdown]
# *ตัวอย่างข้อมูลแบบ 4 มิติ ( 4 Dimension )*

# %% [markdown]
# ***
#
# #### **Type of Data sets : Record Data**
#
# เงื่อนไขคือพยายามหาข้อมูลให้เป็นตัวเลข ลักษณะเด่นๆคือตารางหลายๆตารางต่างมีความสัมพันธ์ดัน (Relationals Records)
#
# หมายเหตุ : Term-frequency คือ ตารางเก็บแบบข้อความ ( Text )

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***
# #### **Type of Data sets : Graphs and Networks**
#
# เหมือนเครือข่ายที่เรารู้จักกันเช่น อินเตอร์เน็ต เครือข่ายการขนส่ง โครงสร้างโมเลกุล เป็นต้น

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***
# #### **Type of Data sets : Ordered Data**
#
# เป็นข้อมูลที่มีตัวเลข หรือ เวลาเข้ามาเกี่ยวข้องเช่น ราคาหุ้น เป็นต้น

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***
#
# ### **Type of Data sets : Spatial, image and multimedia Data**
#
# คือข้อมูลที่เป็นประเภท รูปภาพหรือวิดิโอ

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***
#
# #### **ลักษณะสำคัญข้อมูล**
#
# 1. ข้อมูลมีมิติเป็นยังไง (Dimensionality)
#
# 2. สนใจแค่ที่มีข้อมูล (Sparsity)
#
# 3. ความละเอียดในการเก็บข้อมูล (Resolution)
#
# 4. การกระจายตัวของข้อมูล (Distribution)

# %% [markdown]
# ***
#
# #### **Data Objects**
#
# - Data Sets คือข้อมูลหลายๆข้อมูลมารวมกัน
#
# - Data Object คือข้อมูลแแต่ละตัวประกอบด้วย Entity
#
# - ข้อมูล 1 จุดที่อยู่ในแนวตั้ง (Data 1 จุด คือ Data point)
#
# - ข้อมูลจะถูกอธิบายด้วย Attributes
#
# - ใน Database ที่จะนำมาทำคือ Rows > Data, Column > Attributes

# %% [markdown]
# ****
#
# #### **Attibute Type**
#
# - ข้อมูลแบบ Norminal
# คือข้อมูลที่เป็นการบอกกลุ่มเช่น เพศ อาชีพ เป็นต้น
#
# - ข้อมูลแบบ Binary คือ ข้อมูลเพียงแต่มี 2 สถานะ เช่น ใช่-ไม่ใช่ ถูก-ผิด เป็นต้น โดยแบ่งเป็น 2 แบบได้แก่
#
#  - Symmetric Binary คือสมมาตรกัน
#
#  - Asymmetric Binary คือไม่สมมาตรกัน
#
# - ข้อมูลแบบ Ordinal คือ ข้อมูลที่มีความหมายสามารถนำมาเรียงลำดับหรืออันดับได้

# %% [markdown]
# ***
#
# #### **Numeric Attribute Types**
#
# เรื่องของ ศุนย์แท้กับศูนย์ไม่แท้
#
# 0 แท้ คือ 0 ที่ไม่มีค่าเลยหรือมีค่าเป็น 0 จริงๆ
#
# 0 ไม่แท้ คือ มีค่าเป็นอีกรูปแบบหนึ่งเช่น 00.00 น. เป็นต้น
#
# - ข้อมูลแบบ Interval คือข้อมูลที่ 0 ไม่แท้
#
# - ข้อมูลแบบ Ratio ข้อมูลที่มี 0 แท้

# %% [markdown]
# ***
#
# #### **Discete VS Continuous Attributes**
#
# แบ่งเป็น 2 ลักษณะใหญ่ๆคือ
#
# - Discete Attribute คือ ข้อมูลที่ไม่ต่อเนื่องกัน เช่น รหัสไปรษณีย์ เป็นต้น
# - Continuous Attribute คือ ข้อมูลที่ต่อเนื่องกัน(มีค่าตรงกลาง) โดยข้อมูลส่วนใหญ่เป็นจำนวนจริง เช่น ส่วนสูง 180,181.5,182

# %% [markdown]
# ***
#
# #### **Basic Statistical Descriptions Of Data**
#
# เป็นการดูค่าทางสถิติโดยใช้ค่ากลางมีทั้งหมด 3 ชนิด คือ ค่าเฉลี่ย ค่ามัธฐาน ค่าฐานนิยม
#
# - Movation ตือการเอาค่ากลางทั้ง 3 ตัวมาวาง plot ลงกราฟว่าแตกต่างมากน้อยเพียงใด
#
# - Data Dispersion Characteristcis คือ ค่ากลาง,มากที่สุด,ต่ำสุด,Quantile,Outlines,Varaiance

# %% [markdown]
# ![5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ***
